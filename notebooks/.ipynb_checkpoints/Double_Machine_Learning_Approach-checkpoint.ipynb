# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %%
train = pd.read_csv("../data/raw/non_rand_discount.csv",sep=";")
test = pd.read_csv("../data/raw/random_data.csv")

# %%
# defining a function that replaces US$ for nothing in order to get rid of the non-numerical values
def remove_symbols(discount):
  return float(discount.replace('US$ ', ''))

# %%
train.discount = train.discount.apply(remove_symbols)

# %%
train_two = train[['sales','discount','profit','age','cust_state','tenure','sales_prediction_bins','sales_prediction']]
train_two.head()
# Out:
#      sales  discount  profit  age cust_state  tenure  sales_prediction_bins  \
# 0  3368.64     125.0   40.06   40         MA       6                      8
# 1  2133.10      75.0   29.52   36         MG      10                      4
# 2  2001.62      50.0   48.08   34         RJ       7                      3
# 3  1461.96      10.0   61.64   31         BA       7                      1
# 4  2743.72     100.0   34.44   32         PB       6                      6
#
#    sales_prediction
# 0       1351.024765
# 1       1035.580387
# 2        992.401825
# 3        919.720735
# 4       1176.485681

# %%
# relationship between discount and profit for the train df
plt.figure(figsize=(12,8))
sns.scatterplot(x="profit", y="discount",data=train)
plt.ylabel('Discount,%')
plt.xlabel('Profit,$')
plt.title('Relationship between Discount and Profit')
plt.show()

# %%
# relationship between discount and profit for the test df
plt.figure(figsize=(12,8))
sns.scatterplot(x="profit", y="discount",data=test)
plt.ylabel('Discount,%')
plt.xlabel('Profit,$')
plt.title('Relationship between Discount and Profit')
plt.show()

# %%
# plot of profit by the discount, color represents sales_prediction_bin
plt.figure(figsize=(12,8))
sns.scatterplot(x="discount", y="profit", hue="sales_prediction_bins",data=train)
plt.ylabel('Profit,$')
plt.xlabel('Discount,%')
plt.title('Relationship between Profit and Discount')
plt.show()

# %%
# Looking at the regression of discount on sales we can expect to ___ for each additional unit of discount.
mod = smf.ols(formula='sales ~ profit', data=train)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     6839.
# Date:                Tue, 05 Jul 2022   Prob (F-statistic):               0.00
# Time:                        17:28:21   Log-Likelihood:            -1.2322e+05
# No. Observations:               15000   AIC:                         2.464e+05
# Df Residuals:                   14998   BIC:                         2.465e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1340.8808     15.905     84.303      0.000    1309.704    1372.057
# ...

# %%
profit = np.array([0,500])
sales = 25.8538*profit + 1340.8808

# %%
# Although the linear regresion graph says that it is a good fit, R-squared is pretty close to 0. This gives us strong reasons to believe this positive relationship is biased since we are giving more discounts to customers which we already expect to buy more. 
plt.figure(figsize=(12,8))
sns.scatterplot(x="profit", y="sales", data=train, alpha=0.2, label='sales')
sns.lineplot(x=profit,y=sales, color='red', alpha=1, label='sales = 25.8538*profit + 1340.8808')
plt.ylabel('Sales, $')
plt.xlabel('Profit, $')
plt.legend()
plt.title('Relationship between Sales and Profit')
plt.show()

# %%
# wrong
model = smf.ols(formula='sales ~ profit + sales_prediction_bins', data=train)
results_formula = model.fit()
results_formula.params
x_surf, y_surf = np.meshgrid(np.linspace(train.profit.min(),train.profit.min(),100),np.linspace(train.profit.min(),train.profit.min(),100))
onlyX = pd.DataFrame({'profit':x_surf.ravel(),'sales_prediction_bins':y_surf.ravel()})
fittedY = results_formula.predict(exog=onlyX)
fittedY = np.array(fittedY)

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(train['profit'],train['sales_prediction_bins'],train['sales'],c='blue',marker='o',alpha=0.5)
ax.plot_surface(x_surf,y_surf,fittedY.reshape(x_surf.shape),color='None',alpha=0.3)
ax.set_xlabel('profit')
ax.set_ylabel('sales_prediction_bins')
ax.set_zlabel('sales')
plt.show()
